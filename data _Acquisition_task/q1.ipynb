# %%
#This will not run on online IDE
import requests
from bs4 import BeautifulSoup
 

#url = "http://www.values.com/inspirational-quotes"
# send request to download the data
#response = requests.request("GET", url)

with open("C:/Users/Musad/Desktop/datascience/web1/main.html") as fp:
    data = BeautifulSoup(fp, 'html.parser')

# parse the downloaded data
#data = BeautifulSoup(response.text, 'html.parser')
print(data)
# Out:
# <!DOCTYPE html>
#
# <!-- saved from url=(0045)https://www.passiton.com/inspirational-quotes -->
# <html class="no-js" dir="ltr" lang="en-US"><head><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width,initial-scale=1.0" name="viewport"/>
# <title>Inspirational Quotes - Motivational Quotes - | The Foundation for a Better Life</title>
# <meta content="Find the perfect quotation from our hand-picked collection of inspiring quotes by hundreds of authors." name="description"/>
# <meta content="pass, it, on, passiton, values, kindness" name="keywords"/>
# <meta content="The Foundation for a Better Life" name="twitter:site_name"/>
# <meta content="@passiton_values" name="twitter:site"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="Thank you for visiting." name="twitter:description"/>
# ...

# %%
quotes=[]  # a list to store quotes
  
table = data.find('div', attrs = {'id':'all_quotes'})
  
for row in table.findAll('div',
                         attrs = {'class':'col-6 col-lg-4 text-center margin-30px-bottom sm-margin-30px-top'}):
    quote = {}
    quote['theme'] = row.h5.text
    quote['url'] = row.a['href']
    quote['img'] = row.img['src']
    quote['lines'] = row.img['alt'].split(" #")[0]
    quote['author'] = row.img['alt'].split(" #")[1]
    quotes.append(quote)
print(quotes)
# Out:
# [{'theme': 'SMILE', 'url': 'https://www.passiton.com/inspirational-quotes/7905-just-one-smile-immensely-increases-the-beauty', 'img': './main_files/20220907_wednesday_quote.jpg', 'lines': 'Just one smile, immensely increases the beauty, of the universe.', 'author': '<Author:0x00007ff6829da550>'}, {'theme': 'SMILE', 'url': 'https://www.passiton.com/inspirational-quotes/8145-if-you-see-someone-without-a-smile-give-them', 'img': './main_files/20220906_tuesday_quote.jpg', 'lines': 'If you see someone without a smile, give them one of yours.', 'author': '<Author:0x00007ff6829c2068>'}, {'theme': 'SMILE', 'url': 'https://www.passiton.com/inspirational-quotes/7323-too-often-we-underestimate-the-power-of-a', 'img': './main_files/20220905_monday_quote.jpg', 'lines': 'Too often we underestimate the power of a touch, a smile, a kind word... all of which have the potential to turn a life around.', 'author': '<Author:0x00007ff682a82368>'}, {'theme': 'PEACE', 'url': 'https://www.passiton.com/inspir
# ...

# %%
import pandas as pd

# create a data frame from the list of dictionaries
dataFrame = pd.DataFrame.from_dict(quotes)

dataFrame.head()
# save the scraped data as CSV file
#dataFrame.to_csv('C:\\Users\\Musad\\Desktop\\datascience\\quotes_data.csv', index=False)
# Out:
#                         author                                        img  \
# 0  <Author:0x00007ff6829da550>  ./main_files/20220907_wednesday_quote.jpg
# 1  <Author:0x00007ff6829c2068>    ./main_files/20220906_tuesday_quote.jpg
# 2  <Author:0x00007ff682a82368>     ./main_files/20220905_monday_quote.jpg
# 3  <Author:0x00007ff682a34230>     ./main_files/20220902_friday_quote.jpg
# 4  <Author:0x00007ff682aeb430>   ./main_files/20220901_thursday_quote.jpg
#
#                                                lines  theme  \
# 0  Just one smile, immensely increases the beauty...  SMILE
# 1  If you see someone without a smile, give them ...  SMILE
# 2  Too often we underestimate the power of a touc...  SMILE
# 3  Every breath we take, every step we make, can ...  PEACE
# 4  When we create peace and harmony and balance i...  PEACE
#
#                                                  url
# 0  https://www.passiton.com/inspirational-quotes/...
# ...
